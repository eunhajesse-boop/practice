# %%
c= [1,2,3,5]

result = []
for i in c:
    result.append(i * 2)

print(result)
# Out:
# [2, 4, 6, 10]

# %%
c= [1,2,3,5]
d = [i*2 for i in c]
print(d)
# Out:
# [2, 4, 6, 10]

# %%
d= [[1,2], [3,4], [5,6]]
result_1 = []
result_2 = []

#1
for i in d:
    result_1.append(i[0] + i[1])
print(result_1)

#2
for i, j in d:
    result_2.append(i+j)
print(result_2)
# Out:
# [3, 7, 11]
# [3, 7, 11]

# %%
c= [1,2,3,5]
result = []

for i in c:
    if i % 2 != 0:
        result.append(i)

print(result)

# %%
for i in range(0,6):
    print(i, end = " ")
# Out:
# 0 1 2 3 4 5

# %%
numbers = [0,2,3,5]
square = []
for i in numbers:
    square.append(i * 2)
print(square)

for num in numbers:
    print(num**2)
# Out:
# [0, 4, 6, 10]
# 0
# 4
# 9
# 25

# %%
name = '김판다'
for char in name[::-1]:
    print(char, end = " ")
# Out:
# 다 판 김

# %%
numbers = [1,2,3,4]
total = 0

for num in numbers:
    total += num
print(total)
# Out:
# 10

# %%
def add_one(n):
    return n+1
print(add_one(3))
# Out:
# 4

# %%
def f(x=0, y=1, z=2):
    return x + (2*y) + (3*z)
print (f(y=3))
# Out:
# 12

# %%
print((lambda x: x+1)(2))
#인수 자체가 함수인 경우에 lambda함수가 편리함
#lambda는 함수명 지을 필요 없음
# Out:
# 3

# %%
def add(a,b):
    return a+b
print(add(3,4))
# Out:
# 7

# %%
print((lambda a,b: a+b)(3,4))
# Out:
# 7

# %%
def func (x=0, y=1, z=2):
    return x+y+z
print(func(1,3))
# Out:
# 6

# %%
import math
math.factorial(5)
# Out:
# 120

# %%
from math import factorial
factorial(5)
# Out:
# 120
